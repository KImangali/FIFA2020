# %% [markdown]
# # Analysis of FIFA2020

# %% [markdown]
# ## Content
# + Introduction
# + Objectives
# + Data set
#     + Data preparation
#     + Data validation
#     + Data analysis
# + Conclusion

# %% [markdown]
# <div style="background: #0f214f;">
#     <img src="https://piunikaweb.com/wp-content/uploads/2020/03/image_1585670159337.jpg" width="82%">
# </div>

# %% [markdown]
# # Introduction
# FIFA 20 is a football simulation video game published by Electronic Arts as part of the FIFA series. Each player in FIFA has an overall rating as well as six scores for the key stats; Pace, Shooting, Passing, Dribbling, Defending, and Physical. These stats are combined with a player's international recognition to calculate the player's overall rating.

# %% [markdown]
# <div style="background: #0f214f;">
#     <img src="https://www.footboom.net/img/upload/2/59edc-FIFA-18.jpeg" width="70%">
# </div>

# %% [markdown]
# * short_name - name of the player
# * age - age of the player
# * nationality - country of the player
# * club - his football club where he plays
# * overall - player rating(0-99) in the game
# * value_eur - player value in euro
# * wage_eur - player salary in euro
# * preferred_foot - leading leg
# * international_reputation - player's recognition internationally, player popularity
# * team_position - player's position in the club

# %% [markdown]
# # Objectives

# %% [markdown]
# 1. Clubs and Countries by Players Ratings, Salaries and Reputations
# 2. Players for per country
# 3. Clubs by player value
# 4. Player ratings-to-age ratio and ratings-to-position
# 5. Right-handed vs left-handed

# %% [markdown]
# <h1 name="data_set"> Data set</h1>

# %% [markdown]
# ##  1. Data preparation

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup as BS

# %%
fifa2020_dataset = pd.read_csv('players_20.csv')

# %%
fifa2020_dataset = fifa2020_dataset[['short_name', 'age', 'nationality', 'club', 'overall', 'value_eur', 'wage_eur', 'preferred_foot', 'international_reputation', 'team_position']]

# %%
fifa2020_dataset.shape
# Out:
# (18278, 10)

# %%
fifa2020_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18278 entries, 0 to 18277
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   short_name                18278 non-null  object
#  1   age                       18278 non-null  int64
#  2   nationality               18278 non-null  object
#  3   club                      18278 non-null  object
#  4   overall                   18278 non-null  int64
#  5   value_eur                 18278 non-null  int64
#  6   wage_eur                  18278 non-null  int64
#  7   preferred_foot            18278 non-null  object
#  8   international_reputation  18278 non-null  int64
#  9   team_position             18038 non-null  object
# dtypes: int64(5), object(5)
# memory usage: 1.4+ MB

# %%
fifa2020_dataset.isnull().sum()
# Out:
# short_name                    0
# age                           0
# nationality                   0
# club                          0
# overall                       0
# value_eur                     0
# wage_eur                      0
# preferred_foot                0
# international_reputation      0
# team_position               240
# dtype: int64

# %%
fifa2020_dataset = fifa2020_dataset.dropna()
fifa2020_dataset
# Out:
#          short_name  age          nationality                        club  \
# 17603      R. Darcy   18              England            Bolton Wanderers
# 17185  R. O'Farrell   18  Republic of Ireland                     UCD AFC
# 16940     B. Moreno   19             Colombia              Atlético Huila
# 16959    Chen Kerui   23             China PR  Shandong Luneng TaiShan FC
# 16692  M. Warburton   27              England            Northampton Town
# ...             ...  ...                  ...                         ...
# 59        S. Umtiti   25               France                FC Barcelona
# 62             Isco   27                Spain                 Real Madrid
# 70        T. Müller   29              Germany           FC Bayern München
# 48       D. Mertens   32              Belgium                      Napoli
# 53         K. Navas   32           Costa Rica                 Real Madrid
#
#        overall  value_eur  wage_eur preferred_foot  international_reputation  \
# 17603       53     120000      1000          Right                         1
# 17185       55     160000      1000          Right                         1
# 16940       56     140000      1000          Right                         1
# 16959       56     140000      3000          Right                         1
# 16692       57     120000      3000          Right                         1
# ...        ...        ...       ...            ...                       ...
# 59          86   50000000    210000           Left                         3
# 62          86   51000000    245000          Right                         3
# 70          86   43500000    170000          Right                         4
# 48          87   40000000    135000          Right                         3
# 53          87   30500000    195000          Right                         3
#
#       team_position
# 17603           CAM
# 17185           CAM
# 16940           CAM
# 16959           CAM
# 16692           CAM
# ...             ...
# 59              SUB
# 62              SUB
# 70              SUB
# 48              SUB
# 53              SUB
#
# [18038 rows x 10 columns]

# %%
fifa2020_dataset.sort_values(["team_position", "overall"], axis=0, ascending=True, inplace=True)
fifa2020_dataset
# Out:
#          short_name  age          nationality                        club  \
# 17603      R. Darcy   18              England            Bolton Wanderers
# 17185  R. O'Farrell   18  Republic of Ireland                     UCD AFC
# 16940     B. Moreno   19             Colombia              Atlético Huila
# 16959    Chen Kerui   23             China PR  Shandong Luneng TaiShan FC
# 16692  M. Warburton   27              England            Northampton Town
# ...             ...  ...                  ...                         ...
# 59        S. Umtiti   25               France                FC Barcelona
# 62             Isco   27                Spain                 Real Madrid
# 70        T. Müller   29              Germany           FC Bayern München
# 48       D. Mertens   32              Belgium                      Napoli
# 53         K. Navas   32           Costa Rica                 Real Madrid
#
#        overall  value_eur  wage_eur preferred_foot  international_reputation  \
# 17603       53     120000      1000          Right                         1
# 17185       55     160000      1000          Right                         1
# 16940       56     140000      1000          Right                         1
# 16959       56     140000      3000          Right                         1
# 16692       57     120000      3000          Right                         1
# ...        ...        ...       ...            ...                       ...
# 59          86   50000000    210000           Left                         3
# 62          86   51000000    245000          Right                         3
# 70          86   43500000    170000          Right                         4
# 48          87   40000000    135000          Right                         3
# 53          87   30500000    195000          Right                         3
#
#       team_position
# 17603           CAM
# 17185           CAM
# 16940           CAM
# 16959           CAM
# 16692           CAM
# ...             ...
# 59              SUB
# 62              SUB
# 70              SUB
# 48              SUB
# 53              SUB
#
# [18038 rows x 10 columns]

# %%
fifa2020_dataset.reset_index(drop=True, inplace=True)
fifa2020_dataset
# Out:
#          short_name  age          nationality                        club  \
# 0          R. Darcy   18              England            Bolton Wanderers
# 1      R. O'Farrell   18  Republic of Ireland                     UCD AFC
# 2         B. Moreno   19             Colombia              Atlético Huila
# 3        Chen Kerui   23             China PR  Shandong Luneng TaiShan FC
# 4      M. Warburton   27              England            Northampton Town
# ...             ...  ...                  ...                         ...
# 18033     S. Umtiti   25               France                FC Barcelona
# 18034          Isco   27                Spain                 Real Madrid
# 18035     T. Müller   29              Germany           FC Bayern München
# 18036    D. Mertens   32              Belgium                      Napoli
# 18037      K. Navas   32           Costa Rica                 Real Madrid
#
#        overall  value_eur  wage_eur preferred_foot  international_reputation  \
# 0           53     120000      1000          Right                         1
# 1           55     160000      1000          Right                         1
# 2           56     140000      1000          Right                         1
# 3           56     140000      3000          Right                         1
# 4           57     120000      3000          Right                         1
# ...        ...        ...       ...            ...                       ...
# 18033       86   50000000    210000           Left                         3
# 18034       86   51000000    245000          Right                         3
# 18035       86   43500000    170000          Right                         4
# 18036       87   40000000    135000          Right                         3
# 18037       87   30500000    195000          Right                         3
#
#       team_position
# 0               CAM
# 1               CAM
# 2               CAM
# 3               CAM
# 4               CAM
# ...             ...
# 18033           SUB
# 18034           SUB
# 18035           SUB
# 18036           SUB
# 18037           SUB
#
# [18038 rows x 10 columns]
